# %%
# !python3 ../src/dataset-construction/download_genomes.py --category "archaea" --train_cutoff 2021-12-31 --val_cutoff 2022-12-31 --test_end 2024-12-31 --base_dir "dataset" --dev
# Out:
# 2026-01-15 15:29:02,833 [INFO] Downloading: https://ftp.ncbi.nlm.nih.gov/genomes/genbank/archaea/assembly_summary.txt
# 2026-01-15 15:29:04,397 [WARNING] >>> DEVELOPMENT MODE ACTIVE: Limiting to 100 genomes per split <<<
# 2026-01-15 15:29:04,397 [INFO] TRAIN: 100 genomes
# 2026-01-15 15:29:04,397 [INFO] VAL: 89 genomes
# 2026-01-15 15:29:04,398 [INFO] TEST: 100 genomes
# 2026-01-15 15:29:04,398 [INFO] Downloading TRAIN genomes...
# 2026-01-15 15:30:48,530 [INFO] Downloading VAL genomes...
# 2026-01-15 15:32:24,666 [INFO] Downloading TEST genomes...
# 2026-01-15 15:34:06,346 [INFO] Completed downloading and organizing datasets for category: archaea

# %%
# !python3 ../src/dataset-construction/download_genomes.py --category "bacteria" --train_cutoff 2021-12-31 --val_cutoff 2022-12-31 --test_end 2024-12-31 --base_dir "dataset" --dev
# Out:
# 2026-01-15 15:37:00,983 [INFO] Downloading: https://ftp.ncbi.nlm.nih.gov/genomes/genbank/bacteria/assembly_summary.txt
# 2026-01-15 15:38:00,865 [WARNING] >>> DEVELOPMENT MODE ACTIVE: Limiting to 100 genomes per split <<<
# 2026-01-15 15:38:00,867 [INFO] TRAIN: 100 genomes
# 2026-01-15 15:38:00,867 [INFO] VAL: 100 genomes
# 2026-01-15 15:38:00,868 [INFO] TEST: 100 genomes
# 2026-01-15 15:38:00,868 [INFO] Downloading TRAIN genomes...
# 2026-01-15 15:39:59,100 [INFO] Downloading VAL genomes...
# 2026-01-15 15:42:02,651 [INFO] Downloading TEST genomes...
# 2026-01-15 15:43:51,884 [INFO] Completed downloading and organizing datasets for category: bacteria

# %%
# !python3 ../src/dataset-construction/download_genomes.py --category "fungi" --train_cutoff 2021-12-31 --val_cutoff 2022-12-31 --test_end 2024-12-31 --base_dir "dataset" --dev
# Out:
# 2026-01-15 15:43:52,394 [INFO] Downloading: https://ftp.ncbi.nlm.nih.gov/genomes/genbank/fungi/assembly_summary.txt
# 2026-01-15 15:43:54,142 [WARNING] >>> DEVELOPMENT MODE ACTIVE: Limiting to 100 genomes per split <<<
# 2026-01-15 15:43:54,142 [INFO] TRAIN: 100 genomes
# 2026-01-15 15:43:54,142 [INFO] VAL: 72 genomes
# 2026-01-15 15:43:54,143 [INFO] TEST: 100 genomes
# 2026-01-15 15:43:54,143 [INFO] Downloading TRAIN genomes...
# 2026-01-15 15:47:32,480 [INFO] Downloading VAL genomes...
# 2026-01-15 15:50:02,248 [INFO] Downloading TEST genomes...
# 2026-01-15 15:53:14,556 [INFO] Completed downloading and organizing datasets for category: fungi

# %%
# !python3 ../src/dataset-construction/download_genomes.py --category "protozoa" --train_cutoff 2021-12-31 --val_cutoff 2022-12-31 --test_end 2024-12-31 --base_dir "dataset" --dev
# Out:
# 2026-01-15 15:53:15,164 [INFO] Downloading: https://ftp.ncbi.nlm.nih.gov/genomes/genbank/protozoa/assembly_summary.txt
# 2026-01-15 15:53:16,042 [WARNING] >>> DEVELOPMENT MODE ACTIVE: Limiting to 100 genomes per split <<<
# 2026-01-15 15:53:16,042 [INFO] TRAIN: 18 genomes
# 2026-01-15 15:53:16,042 [INFO] VAL: 4 genomes
# 2026-01-15 15:53:16,042 [INFO] TEST: 13 genomes
# 2026-01-15 15:53:16,042 [INFO] Downloading TRAIN genomes...
# 2026-01-15 15:53:46,724 [INFO] Downloading VAL genomes...
# 2026-01-15 15:53:52,695 [INFO] Downloading TEST genomes...
# 2026-01-15 15:54:14,387 [INFO] Completed downloading and organizing datasets for category: protozoa

# %%
# !python3 ../src/dataset-construction/download_genomes.py --category "viral" --train_cutoff 2021-12-31 --val_cutoff 2022-12-31 --test_end 2024-12-31 --base_dir "dataset" --dev
# Out:
# 2026-01-15 15:54:15,272 [INFO] Downloading: https://ftp.ncbi.nlm.nih.gov/genomes/genbank/viral/assembly_summary.txt
# 2026-01-15 15:54:20,358 [WARNING] >>> DEVELOPMENT MODE ACTIVE: Limiting to 100 genomes per split <<<
# 2026-01-15 15:54:20,366 [INFO] TRAIN: 100 genomes
# 2026-01-15 15:54:20,367 [INFO] VAL: 100 genomes
# 2026-01-15 15:54:20,367 [INFO] TEST: 100 genomes
# 2026-01-15 15:54:20,367 [INFO] Downloading TRAIN genomes...
# 2026-01-15 15:55:28,622 [INFO] Downloading VAL genomes...
# 2026-01-15 15:56:37,527 [INFO] Downloading TEST genomes...
# 2026-01-15 15:57:46,287 [INFO] Completed downloading and organizing datasets for category: viral
